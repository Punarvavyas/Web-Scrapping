# %%
import requests
from bs4 import BeautifulSoup

# %%
page_cs = requests.get("https://www.dal.ca/faculty/computerscience/faculty-staff.html")
page_be = requests.get("https://www.dal.ca/faculty/school-biomedical-engineering/our-people/our-faculty-atok.html")
page_ee = requests.get("https://www.dal.ca/faculty/engineering/electrical/faculty-staff.html")
print(page_cs.status_code)
print(page_cs.content)
soup_cs = BeautifulSoup(page_cs.content, 'html.parser') 
soup_be = BeautifulSoup(page_be.content, 'html.parser') 
soup_ee = BeautifulSoup(page_ee.content,'html.parser')
# Out:
# 200
# b'<!DOCTYPE html>\n<html >\n<head>\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n    <meta name="keywords" content="" />\n    <meta name="description" content=""/>\n    <meta name="coveoDate" content="2019-09-23T12:16:26Z" /><link rel="shortcut icon" href="https://cdn.dal.ca/etc/designs/dalhousie/clientlibs/global/default/images/favicon/favicon.ico.lt_cf5aed4779c03bd30d9b52d875efbe6c.res/favicon.ico"/>\n<link rel="apple-touch-icon" sizes="57x57" href="https://cdn.dal.ca/etc/designs/dalhousie/clientlibs/global/default/images/favicon/apple-touch-icon-57x57.png.lt_ae6cddc0ec58c6ad0db492db183a7861.res/apple-touch-icon-57x57.png"/>\n<link rel="apple-touch-icon" sizes="114x114" href="https://cdn.dal.ca/etc/designs/dalhousie/clientlibs/global/default/images/favicon/apple-touch-icon-114x114.png.lt_84b32f81f79631253e6176ec40ca2de9.res/apple-touch-icon-114x114.png"/>\n<link rel="apple-touch-icon" sizes="72x72" href="https://cdn.dal.ca/etc/designs/dalhousie/clientlibs/global/default/images/favicon/apple-touch-icon-72x72.png.lt_dded2f4fd858f27de8672ab9a4c89504.res/apple-touch-icon-72x72.png"/>\n<link rel="apple-touch-icon" sizes="144x144" href="https://cdn.dal.ca/etc/designs/dalhousie/clientlibs/global/default/images/favicon/apple-touch-icon-144x144.png.lt_e2ee94a9eaa76603b741204d24623b93.res/apple-touch-icon-144x144.png"/>\n<link rel="apple-touch-icon" sizes="60x60" href="https://cdn.dal.ca/etc/designs/dalhousie/clientlibs/global/default/images/favicon/apple-touch-icon-60x60.png.lt_c4d25faff593461b28aa34641414b843.res/apple-touch-icon-60x60.png"/>\n<link rel="apple-touch-icon" sizes="120x120" href="https://cdn.dal.ca/etc/designs/dalhousie/clientlibs/global/default/images/favicon/apple-touch-icon-120x120.png.lt_7d855ca88619263ebe9d0b425f8beefb.res/apple-touch-icon-120x120.png"/>\n<link rel="apple-touch-icon" sizes="76x76" href="https://cdn.dal.ca/etc/designs/dalhousie/clientlibs/global/default/images/favicon/apple-touch-icon-76x76.png.lt_7a2d766388dd80a41b93205cd5b780ba.res/apple-touch-icon-76x76.png"/>\n<link rel="apple-touch-icon" sizes="152x152" href="https://cdn.dal.ca/etc/designs/dalhousie/clientlibs/global/default/images/favicon/apple-touch-icon-152x152.png.lt_0440d531128bc5759dba6477f760066b.res/apple-touch-icon-152x152.png"/>\n<link rel="icon" type="image/png" href="https://cdn.dal.ca/etc/designs/dalhousie/clientlibs/global/default/images/favicon/favicon-196x196.png.lt_0edbdb9324a882d56c94bc96784e35fd.res/favicon-196x196.png" sizes="196x196"/>\n<link rel="icon" type="image/png" href="https://cdn.dal.ca/etc/designs/dalhousie/clientlibs/global/default/images/favicon/favicon-160x160.png.lt_8df22da316bd95b0a09176e5ec951995.res/favicon-160x160.png" sizes="160x160"/>\n<link rel="icon" type="image/png" href="https://cdn.dal.ca/etc/designs/dalhousie/clientlibs/global/default/images/favicon/favicon-96x96.png.lt_99f65cb862044f8ef23bdf522c69c6f1.res/favicon-96x96.png" sizes="96x96"/>\n<link rel="icon" type="image/png" href="https://cdn.dal.ca/etc/designs/dalhousie/clientlibs/global/default/images/favicon/favicon-16x16.png.lt_cea27605b7664f8e629185cdb7f1d971.res/favicon-16x16.png" sizes="16x16"/>\n<link rel="icon" type="image/png" href="https://cdn.dal.ca/etc/designs/dalhousie/clientlibs/global/default/images/favicon/favicon-32x32.png.lt_35cf41d8172133bd755a153173baaac5.res/favicon-32x32.png" sizes="32x32"/>\n\n<meta name="application-name" content="Dalhousie University" />\n    <meta name="msapplication-starturl" content="https://www.dal.ca" />\n    <meta name="msapplication-TileColor" content="#ffc40d" />\n    <meta name="msapplication-TileImage" content="/etc/designs/dalhousie/clientlibs/global/default/images/favicon/mstile-144x144.png" />\n    <meta name="msapplication-config" content="/etc/designs/dalhousie/clientlibs/global/default/images/favicon/browserconfig.xml" />\n\n    <meta name="mobile-web-app-capable" content="yes" />\n    <meta name="apple-mobile-web-app-capable" content="yes" />\n    <meta name=" ...

# %%
proffesor_name = soup_cs.find_all('div', attrs={ "class" : "text parbase section"})
proffesor_detail= soup_be.find_all('div', attrs={ "class" : "text parbase section"})
proffesor_names=soup_ee.find_all('div',attrs={"class":"text parbase section"})
#print(proffesor_name)
file1 = open("untitled.xml","w+") 
file2 = open("untitled1.xml","w+")
file3=open("department.xml","w+")
xml_str = "<root>"

ctr=1
for ele in proffesor_name:
    links = ele.find_all('a')
#     print(links)
    for i, names in enumerate(links):
        if not '@' in names.text:
            if 'Dr' in names.text or 'Mr' in names.text: 
                print(names.text)
                xml_str = xml_str + "<record><field name=\"professor_id\">"+str(ctr)+"</field><field name=\"professor_name\">"+names.text+"</field><field name=\"professor_lname\">"+names.text.replace("Dr.","").split(" ")[2]+"</field><field name=\"iddepartment\">1</field></record>"
                ctr=ctr+1
xml_str+="</root>"
file1.write(xml_str)
                
file1.close()       
print ("endddddddddddd")   
xml_str = "<root>"
ctr=37
for ele in proffesor_detail:
    links = ele.find_all('a')
    
    for names in links:
        if not '@' in names.text:
            if not 'http:' in names.text and not 'www.' in names.text:
                print(names.text)
                xml_str = xml_str + "<record><field name=\"professor_id\">"+str(ctr)+"</field><field name=\"professor_name\">"+names.text+"</field><field name=\"professor_lname\">"+names.text.split(" ")[1]+"</field><field name=\"iddepartment\">2</field></record>"
                ctr=ctr+1
                

xml_str+="</root>" 
file2.write(xml_str)
                
file2.close() 
print("enddddddddddddddddddddddddddddddddd")    

file3.write("<root><record><field name=\"iddepartment\">1</field><field name=\"department name\">Computer_Science</field></record><record><field name=\"iddepartment\">2</field><field name=\"department name\">Biomedical engineering</field></record></root>")
file3.close()
for ele in proffesor_names:
    links = ele.find_all('td')
    #print(links)
    #link_temp=links[5:]
    #print(link_temp)
    
    for names in links[5:-2]:
        
        if not '@' in names.text:
            if not '(902)' in names.text and not 'www.' in names.text:
                
                    print(names.text) 
                   # print("hi")
# Out:
# Dr. A. Rau-Chaplin
# Dr. Robert Beiko
# Dr. Christian Blouin
# Dr. Raza Abidi
# Dr. Dirk Arnold
# Dr. J. Blustein
# Dr. Peter Bodorik
# Dr. Stephen Brooks
# Dr. Israat Haque
# Dr. Meng He
# Dr. Malcolm Heywood
# Dr. Vlado Keselj
# Dr. Joseph Malloch
# Dr. Stan Matwin
# Dr. Michael McAllister
# Dr. Evangelos E. Milios
# Dr. Sageev Oore
# Dr. Rita Orji
# Dr. Fernando Paulovich
# Dr. Paul Ralph
# Dr. Derek Reilly
# Dr. Srinivas Sampalli
# Dr. Luis Torgo
# Dr. T. Trappenberg
# Dr. Carolyn R. Watters
# Dr. Qiang Ye
# Dr. Norbert Zeh
# Dr. N. Zincir-Heywood
# Dr. Khurram Aziz
# Dr. Alex Brodsky
# Mr. James Fleming
# Dr. Kirstie Hawkey
# Dr. N. Kalyaniwalla
# Dr. Bonnie MacKay
# Dr. Raghav Sampangi
# Dr. Angela Siegel
# endddddddddddd
# Geoffrey Maksym
# Jeremy Brown
# Robert Adamson
# Manohar Bance
# Steven Beyea
# Daniel Boyd
# Kimberly Brewer
# Jeremy Brown
# Michael Dunbar
# Ron El-Hawary
# James Ellsmere
# Mark Filiaggi
# Alan Fine
# John Frampton
# Andrew French
# Amyl Ghanem
# Paul Gratzer
# Jason Gu
# Gabrielle Horne
# Cheryl Kozey
# John Kozey
# Laurent Kreplak
# Faculty members L-Z
# enddddddddddddddddddddddddddddddddd
# Jean-François Bousquet
# C368
# Undergraduate Advisor
# Ghada Koleilat
# P2233
# Graduate Advisor
# Dmitry Trukhachev
#
# K Bldg
#
# Co-Op Advisor
# Jose Gonzalez-Cueto
# C315
# Administrator
# Jascinth Butterfield
# C306
# Administrative & Undergraduate Secretary
# Nicole Smith
# C367
# Graduate Secretary
# Rebecca Baccardax
# Rob Adamson (joint-appointment)
# VG Site
# Biomedical Engineering
# Jeremy Brown (joint-appointment)
# VG Site
# Biomedical Engineering
# Jean-François Bousquet
# K Bldg
# Microelectronics, Communications
# Michael Cada
# C310
# Photonics / Fiber Optics
# Zhizhang (David) Chen, Fellow of IEEE, CAE, EIC
# C368
# Electromagnetics, Antenna, Wireless Technology
# Dr. Ezz El-Masry
# C308
# Microelectronics
# Dr. Kamal El-Sankary
# C371
# Microelectronics, Embedded Systems
# Michael Freund (Cross-appointment)
#
# Electronic Materials, Sensing
# Jose Gonzales-Cueto
# C315
# Signal Processing
# Jason Gu, Fellow of CAE and EIC
# C312
# Control, Robotics, Biomedical
# Larry Hughes
# C369
# Energy Systems, Computer Engineering
# Jacek Ilow
# C250
# Signal Processing, Communications, Networks
# Ghada Koleilat
# P2233
# Nanomaterials for Energy Conversion and Sensing
# Joshua Leon, Fellow of CAE and FEC
#
# M108
# Uniacke House, 2nd floor
# Computational Electronics, Biomedical
# Colin O'Flynn
# TBD
# IDEA Building 2003
# Cyber Security, Embedded Systems
# Mae L. Seto (cross-appointment)
# C303
# Robotic autonomy, controls, multi-agent systems, ocean engineering
# Vincent Sieben
# C301
# Microfluidics, Lab-on-a-Chip, Ocean Sensors, Energy
# Timothy Little, Associate Dean of Engineering
# C316
# Power, Electromechanics
# Yuan Ma
# C314
# Microelectronics, MEMS
# Sergey Ponomarenko
# C313
# Photonics, Fiber Optics, Optical Physics
# Dmitry Trukhachev
# K Bldg
# C367
# Peter Gregson
#
# C235B
# Paul Hines
#
# C367
# Peng Jin
# C367
# Aaron MacNeill
# C325
#
# Allan Marble (Emeritus)
#
# C235B
#
# Mark McIntyre
#
# C367
# Hong Nie
#
# C367
# Christian Schlegel
# K204
# Yiqiang (Johnny) Yu
# IDEA Building 2011A
# Alex Pudsey
# IDEA Building 2011A
# Tyler Seize
#
#
# Jordan Wright
